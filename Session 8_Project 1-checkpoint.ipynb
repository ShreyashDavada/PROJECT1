# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df5 = pd.read_csv('C:\Users\shreyash.davada\Desktop\data-text_assignment8.csv')

# %%
df10 = pd.read_csv('C:\Users\shreyash.davada\Desktop\data-text_assignment8.1.csv')

# %%
df5.describe
# Out:
# <bound method DataFrame.describe of                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
df10.describe
# Out:
# <bound method DataFrame.describe of                   STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 0       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999
# 1       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999
# 2       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999
# 3       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999
# 4       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999
# 5       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310107    10 -9999 -9999
# 6       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310108    13 -9999 -9999
# 7       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310109    10 -9999 -9999
# 8       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310110 -9999 -9999 -9999
# 9       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310112 -9999 -9999 -9999
# 10      GHCND:GME00111445  BERLIN TEMPELHOF GM  19310113    13 -9999 -9999
# ...

# %%
df5.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df10.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
columnsNamesArr = df5.columns.values

# %%
columnsNamesArr
# Out:
# array(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value',
#        'Numeric', 'Low', 'High', 'Comments'], dtype=object)

# %%
columnsNamesArr2 = df10.columns.values

# %%
columnsNamesArr2
# Out:
# array(['STATION', 'STATION_NAME', 'DATE', 'PRCP', 'SNWD', 'SNOW', 'TMAX',
#        'TMIN', 'WDFG', 'PGTM', 'WSFG', 'WT09', 'WT07', 'WT01', 'WT06',
#        'WT05', 'WT04', 'WT16', 'WT08', 'WT18', 'WT03'], dtype=object)

# %%
df1 = df5.rename(columns={'Indicator': 'Indicator_NEW1', 'Year': 'NEW_Year', 'Sex' : 'Sex_New'})

# %%
df1.columns.values
# Out:
# array(['Indicator_NEW1', 'PUBLISH STATES', 'NEW_Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex_New', 'Display Value',
#        'Numeric', 'Low', 'High', 'Comments'], dtype=object)

# %%
df1
# Out:
#                                        Indicator_NEW1 PUBLISH STATES  \
# 0                    Life expectancy at birth (years)      Published
# 1                    Life expectancy at birth (years)      Published
# 2                   Life expectancy at age 60 (years)      Published
# 3                   Life expectancy at age 60 (years)      Published
# 4                    Life expectancy at birth (years)      Published
# 5                    Life expectancy at birth (years)      Published
# 6                   Life expectancy at age 60 (years)      Published
# 7                   Life expectancy at age 60 (years)      Published
# 8                    Life expectancy at birth (years)      Published
# 9                    Life expectancy at birth (years)      Published
# 10                   Life expectancy at birth (years)      Published
# 11                   Life expectancy at birth (years)      Published
# 12                  Life expectancy at age 60 (years)      Published
# ...

# %%
df1.NEW_Year.values.sort()

# %%
df1
# Out:
#                                        Indicator_NEW1 PUBLISH STATES  \
# 0                    Life expectancy at birth (years)      Published
# 1                    Life expectancy at birth (years)      Published
# 2                   Life expectancy at age 60 (years)      Published
# 3                   Life expectancy at age 60 (years)      Published
# 4                    Life expectancy at birth (years)      Published
# 5                    Life expectancy at birth (years)      Published
# 6                   Life expectancy at age 60 (years)      Published
# 7                   Life expectancy at age 60 (years)      Published
# 8                    Life expectancy at birth (years)      Published
# 9                    Life expectancy at birth (years)      Published
# 10                   Life expectancy at birth (years)      Published
# 11                   Life expectancy at birth (years)      Published
# 12                  Life expectancy at age 60 (years)      Published
# ...

# %%
df1 = df1[['Country','Indicator_NEW1','PUBLISH STATES','WHO region','World Bank income group','Sex_New','Display Value','Numeric','Low','High','Comments']]

# %%
df1
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 5                    Antigua and Barbuda
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 12                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
df5
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
df5.loc

# %%
df5.loc[11]
# Out:
# Indicator                  Life expectancy at birth (years)
# PUBLISH STATES                                    Published
# Year                                                   2012
# WHO region                                           Europe
# World Bank income group                         High-income
# Country                                             Austria
# Sex                                                  Female
# Display Value                                            83
# Numeric                                                  83
# Low                                                     NaN
# High                                                    NaN
# Comments                                                NaN
# Name: 11, dtype: object

# %%
df5.loc[24]
# Out:
# Indicator                  Life expectancy at age 60 (years)
# PUBLISH STATES                                     Published
# Year                                                    2012
# WHO region                                   Western Pacific
# World Bank income group                          High-income
# Country                                    Brunei Darussalam
# Sex                                                   Female
# Display Value                                             21
# Numeric                                                   21
# Low                                                      NaN
# High                                                     NaN
# Comments                                                 NaN
# Name: 24, dtype: object

# %%
df5.loc[37]
# Out:
# Indicator                  Life expectancy at age 60 (years)
# PUBLISH STATES                                     Published
# Year                                                    2012
# WHO region                                            Europe
# World Bank income group                          High-income
# Country                                               Cyprus
# Sex                                                   Female
# Display Value                                             26
# Numeric                                                   26
# Low                                                      NaN
# High                                                     NaN
# Comments                                                 NaN
# Name: 37, dtype: object

# %%
df5.drop(df.index[[5,12,23,56]])
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# 11                   Life expectancy at birth (years)      Published  2012
# ...

# %%
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')

# %%
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')

# %%
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')

# %%
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
products
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
merger1 = pd.merge(users,transactions)

# %%
merger1
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN              4
# 1       2     Pedro    male  2010-08-01  2010-08-08              5
# 2       2     Pedro    male  2010-08-01  2010-08-08              6
# 3       3  Caroline  female  2012-10-23  2016-06-07              2
# 4       3  Caroline  female  2012-10-23  2016-06-07              3
# 5       3  Caroline  female  2012-10-23  2016-06-07              7
# 6       3  Caroline  female  2012-10-23  2016-06-07             10
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26          2         3
# 1      2013-06-06          4         1
# 2      2013-12-23          5         6
# 3      2011-05-26          4         1
# 4      2011-06-16          3         1
# 5      2013-12-30          4         1
# 6      2016-05-08          4         4

# %%
merger2 = pd.merge(transactions,users)

# %%
merger2
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
merger3 = pd.merge(merger2,products)

# %%
merger3
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              7      2013-12-30     3.0          4         1  Caroline
# 2             10      2016-05-08     3.0          4         4  Caroline
# 3              5      2013-06-06     2.0          4         1     Pedro
# 4              3      2011-06-16     3.0          3         1  Caroline
# 5              4      2012-08-26     1.0          2         3   Charles
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled Product  Price
# 0  female  2012-10-23  2016-06-07       D  10.02
# 1  female  2012-10-23  2016-06-07       D  10.02
# 2  female  2012-10-23  2016-06-07       D  10.02
# 3    male  2010-08-01  2010-08-08       D  10.02
# 4  female  2012-10-23  2016-06-07       C  10.65
# 5    male  2012-12-21         NaN       B  33.04
# ...

# %%
merger4 = pd.merge(merger3,sessions)

# %%
merger4
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              7      2013-12-30     3.0          4         1  Caroline
# 2             10      2016-05-08     3.0          4         4  Caroline
# 3              3      2011-06-16     3.0          3         1  Caroline
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              5      2013-06-06     2.0          4         1     Pedro
# 7              6      2013-12-23     2.0          5         6     Pedro
# 8              6      2013-12-23     2.0          5         6     Pedro
# 9              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled Product  Price  SessionID SessionDate
# 0  female  2012-10-23  2016-06-07       D  10.02          7  2012-12-21
# ...

# %%
pd.concat([users,sessions,products,transactions],axis=1)
# Out:
#    UserID      User  Gender  Registered   Cancelled  SessionID SessionDate  \
# 0     1.0   Charles    male  2012-12-21         NaN          1  2010-01-05
# 1     2.0     Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 2     3.0  Caroline  female  2012-10-23  2016-06-07          3  2010-11-25
# 3     4.0   Brielle  female  2013-07-17         NaN          4  2011-09-21
# 4     5.0  Benjamin    male  2010-11-25         NaN          5  2011-10-19
# 5     NaN       NaN     NaN         NaN         NaN          6  2012-10-23
# 6     NaN       NaN     NaN         NaN         NaN          7  2012-12-21
# 7     NaN       NaN     NaN         NaN         NaN          8  2013-05-22
# 8     NaN       NaN     NaN         NaN         NaN          9  2013-07-17
# 9     NaN       NaN     NaN         NaN         NaN         10  2016-01-11
#
#    UserID  ProductID Product  Price  TransactionID TransactionDate  UserID  \
# ...

# %%
mg = pd.merge(users,sessions,how='inner',on='UserID')

# %%
mg
# Out:
#    UserID      User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2     Pedro    male  2010-08-01  2010-08-08          1  2010-01-05
# 1       2     Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 2       2     Pedro    male  2010-08-01  2010-08-08          3  2010-11-25
# 3       3  Caroline  female  2012-10-23  2016-06-07          7  2012-12-21
# 4       4   Brielle  female  2013-07-17         NaN          5  2011-10-19
# 5       4   Brielle  female  2013-07-17         NaN          6  2012-10-23
# 6       4   Brielle  female  2013-07-17         NaN          8  2013-05-22
# 7       4   Brielle  female  2013-07-17         NaN          9  2013-07-17
# 8       4   Brielle  female  2013-07-17         NaN         10  2016-01-11
# 9       5  Benjamin    male  2010-11-25         NaN          4  2011-09-21

# %%
mg.reset_index()
# Out:
#    index  UserID      User  Gender  Registered   Cancelled  SessionID  \
# 0      0       2     Pedro    male  2010-08-01  2010-08-08          1
# 1      1       2     Pedro    male  2010-08-01  2010-08-08          2
# 2      2       2     Pedro    male  2010-08-01  2010-08-08          3
# 3      3       3  Caroline  female  2012-10-23  2016-06-07          7
# 4      4       4   Brielle  female  2013-07-17         NaN          5
# 5      5       4   Brielle  female  2013-07-17         NaN          6
# 6      6       4   Brielle  female  2013-07-17         NaN          8
# 7      7       4   Brielle  female  2013-07-17         NaN          9
# 8      8       4   Brielle  female  2013-07-17         NaN         10
# 9      9       5  Benjamin    male  2010-11-25         NaN          4
#
#   SessionDate
# 0  2010-01-05
# 1  2010-08-01
# 2  2010-11-25
# 3  2012-12-21
# 4  2011-10-19
# 5  2012-10-23
# 6  2013-05-22
# 7  2013-07-17
# 8  2016-01-11
# 9  2011-09-21

# %%
mr = merger3+merger4

# %%
mr
# Out:
#               Cancelled        Gender  Price Product  ProductID  Quantity  \
# 0  2016-06-072016-06-07  femalefemale  20.04      DD        8.0       2.0
# 1  2016-06-072016-06-07  femalefemale  20.04      DD        8.0       2.0
# 2  2016-06-072016-06-07  femalefemale  20.04      DD        8.0       8.0
# 3  2010-08-082016-06-07    malefemale  20.67      DC        7.0       2.0
# 4  2016-06-072010-08-08    femalemale  20.67      CD        7.0       2.0
# 5                   NaN      malemale  43.06      BD        6.0       4.0
# 6  2010-08-082010-08-08      malemale  39.68      ED        9.0       7.0
# 7                   NaN           NaN    NaN     NaN        NaN       NaN
# 8                   NaN           NaN    NaN     NaN        NaN       NaN
# 9                   NaN           NaN    NaN     NaN        NaN       NaN
#
#              Registered SessionDate  SessionID       TransactionDate  \
# 0  2012-10-232012-10-23         NaN        NaN  2011-05-262011-05-26
# ...

# %%
mr.index.names
# Out:
# FrozenList([None])
